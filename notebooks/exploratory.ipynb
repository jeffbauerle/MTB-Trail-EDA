# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import json_normalize
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# Denver
denver_file = '../data/denver.json'

with open(denver_file) as denver_file:
  denver = json.load(denver_file)

# %%
# Park City
park_city_file = '../data/parkcity.json'

with open(park_city_file) as park_city_file:
  park_city = json.load(park_city_file)

# %%
# Moab
moab_file = '../data/moab.json'

with open(moab_file) as moab_file:
  moab = json.load(moab_file)

# %%
# Sedona
sedona_file = '../data/sedona.json'

with open(sedona_file) as sedona_file:
  sedona = json.load(sedona_file)

# %%
# Marin County
marin_county_file = '../data/marincounty.json'

with open(marin_county_file) as marin_county_file:
  marin_county = json.load(marin_county_file)

# %%
# Crested Butte
crested_butte_file = '../data/crestedbutte.json'

with open(crested_butte_file) as crested_butte_file:
  crested_butte = json.load(crested_butte_file)

# %%
denver_trails = denver['trails']
denver_df = json_normalize(denver_trails)
denver_df["location"] = "denver"

# %%
denver_df.head()
# Out:
#         id                                      name               type  \
# 0  7015764                 Little Scraggy Trail Loop  Recommended Route
# 1   845269        Buffalo Creek Big Loop - IMBA EPIC  Recommended Route
# 2   858508  Buffalo Creek Loop - Pine Lake Trailhead  Recommended Route
# 3    31804                           Centennial Cone  Recommended Route
# 4    46286                          Betasso Preserve  Recommended Route
#
#                                              summary difficulty  stars  \
# 0  A great, new flow trail at Buffalo Creek, whic...  blueBlack    4.7
# 1  A nice tour of some of the best of Buffalo Cre...       blue    4.6
# 2  A nice tour of popular Buffalo Creek trails on...       blue    4.3
# 3  One of the better beginner/intermediate rides ...       blue    4.1
# 4  A solid ride close to Boulder that is often ri...       blue    4.1
#
#    starVotes location                                                url  \
# 0        570   denver  https://www.mtbproject.com/trail/7015764/littl...
# 1        295   denver  https://www.mtbproject.com/trail/845269/buffal...
# 2         83   denver  https://www.mtbproject.com/trail/858508/buffal...
# 3        337   denver  https://www.mtbproject.com/trail/31804/centenn...
# 4        264   denver  https://www.mtbproject.com/trail/46286/betasso...
#
#                                           imgSqSmall  ... length ascent  \
# 0  https://cdn2.apstatic.com/photos/mtb/7011149_s...  ...   12.6   1432
# 1  https://cdn2.apstatic.com/photos/mtb/7013659_s...  ...   24.2   2590
# 2  https://cdn2.apstatic.com/photos/mtb/7031299_s...  ...   20.6   2418
# 3  https://cdn2.apstatic.com/photos/mtb/7029901_s...  ...   17.2   2340
# 4  https://cdn2.apstatic.com/photos/mtb/7002944_s...  ...    7.4    829
#
#   descent  high   low  longitude  latitude  conditionStatus  \
# 0   -1443  8534  7659  -105.2573   39.3443        All Clear
# 1   -2586  8054  6672  -105.2744   39.3866        All Clear
# 2   -2422  8051  6865  -105.3473   39.4083     Minor Issues
# 3   -2348  7911  6804  -105.3710   39.7372        All Clear
# 4    -829  6589  6178  -105.3422   40.0155        All Clear
#
#         conditionDetails        conditionDate
# 0                    Dry  2020-07-20 11:16:52
# 1                    Dry  2020-07-19 12:23:29
# 2  Dry - Very loose dirt  2020-07-03 15:00:14
# 3                    Dry  2020-07-18 09:40:59
# 4                    Dry  2020-07-17 16:55:32
#
# [5 rows x 23 columns]

# %%
print(round(denver_df['stars'].mean(),2))
# Out:
# 3.95

# %%
park_city_trails = park_city['trails']
park_city_df = json_normalize(park_city_trails)
park_city_df["location"] = "park_city"

# %%
print(round(park_city_df['stars'].mean(),2))
# Out:
# 4.09

# %%
moab_trails = moab['trails']
moab_df = json_normalize(moab_trails)
moab_df["location"] = "moab"

print(round(moab_df['length'].mean(),2))
# Out:
# 12.2

# %%
sedona_trails = sedona['trails']
sedona_df = json_normalize(sedona_trails)
sedona_df["location"] = "sedona"

print(round(sedona_df['length'].mean(),2))
# Out:
# 6.75

# %%
marin_county_trails = marin_county['trails']
marin_county_df = json_normalize(marin_county_trails)
marin_county_df["location"] = "marin_county"

print(round(marin_county_df['length'].mean(),2))
# Out:
# 5.6

# %%
crested_butte_trails = crested_butte['trails']
crested_butte_df = json_normalize(crested_butte_trails)
crested_butte_df["location"] = "crested_butte"

print(round(crested_butte_df['length'].mean(),2))
# Out:
# 11.37

# %%
crested_butte_df.describe()
# Out:
#                  id       stars  starVotes      length        ascent  \
# count  2.000000e+02  200.000000  200.00000  200.000000    200.000000
# mean   5.137630e+06    4.344000   19.47500   11.373500   1373.710000
# std    2.275695e+06    0.505909   36.86713   20.439846   2425.454043
# min    4.266900e+04    2.700000    1.00000    0.100000      0.000000
# 25%    3.733432e+06    4.000000    5.00000    1.700000     59.000000
# 50%    6.083405e+06    4.400000   10.50000    5.300000    506.500000
# 75%    7.019166e+06    4.700000   20.00000   14.200000   1804.000000
# max    7.053466e+06    5.000000  329.00000  195.300000  20862.000000
#
#             descent          high           low   longitude    latitude
# count    200.000000    200.000000    200.000000  200.000000  200.000000
# mean   -1703.645000   9683.070000   8413.620000 -106.866169   38.972936
# std     2353.387089   1751.812682   1277.012561    0.440124    0.364290
# min   -20196.000000   5566.000000   5437.000000 -108.545600   38.168000
# 25%    -2225.500000   8315.750000   7693.750000 -107.042350   38.731900
# 50%    -1142.500000   9805.000000   8535.000000 -106.927250   38.945550
# 75%     -309.250000  10943.000000   9443.250000 -106.679575   39.225575
# max        0.000000  14418.000000  11082.000000 -105.995200   39.640000

# %%
# Columns
crested_butte_df.columns
# Out:
# Index(['id', 'name', 'type', 'summary', 'difficulty', 'stars', 'starVotes',
#        'location', 'url', 'imgSqSmall', 'imgSmall', 'imgSmallMed', 'imgMedium',
#        'length', 'ascent', 'descent', 'high', 'low', 'longitude', 'latitude',
#        'conditionStatus', 'conditionDetails', 'conditionDate'],
#       dtype='object')

# %%
cb_unique = crested_butte_df.copy()
cb_unique = cb_unique.groupby("difficulty")

# %%
cb_unique["difficulty"].unique()
# Out:
# difficulty
# black            [black]
# blue              [blue]
# blueBlack    [blueBlack]
# dblack          [dblack]
# green            [green]
# greenBlue    [greenBlue]
# Name: difficulty, dtype: object

# %%
crested_butte_df[crested_butte_df["difficulty"] == "green"]["stars"].mean()
# Out:
# 4.3

# %%
crested_butte_df[crested_butte_df["difficulty"] == "greenBlue"]["stars"].mean()
# Out:
# 4.425

# %%
crested_butte_df[crested_butte_df["difficulty"] == "blue"]["stars"].mean()
# Out:
# 4.451666666666667

# %%
crested_butte_df[crested_butte_df["difficulty"] == "blueBlack"]["stars"].mean()
# Out:
# 4.266666666666666

# %%
crested_butte_df[crested_butte_df["difficulty"] == "black"]["stars"].mean()
# Out:
# 4.265060240963854

# %%
crested_butte_df[crested_butte_df["difficulty"] == "dblack"]["stars"].mean()
# Out:
# 4.569999999999999

# %%
crested_butte_df.groupby("difficulty")["stars"].mean()
# Out:
# difficulty
# black        4.265060
# blue         4.451667
# blueBlack    4.266667
# dblack       4.570000
# green        4.300000
# greenBlue    4.425000
# Name: stars, dtype: float64

# %%
crested_butte_df.groupby("difficulty")["stars"].agg([min,max,sum])
# Out:
#             min  max    sum
# difficulty
# black       2.7  5.0  354.0
# blue        3.0  5.0  267.1
# blueBlack   2.8  5.0  140.8
# dblack      4.0  5.0   45.7
# green       3.5  5.0   25.8
# greenBlue   4.0  4.8   35.4

# %%
crested_butte_df.pivot_table(values="stars",index="difficulty", aggfunc=[np.mean, np.median, np.min, np.max])
# Out:
#                 mean median  amin  amax
#                stars  stars stars stars
# difficulty
# black       4.265060   4.40   2.7   5.0
# blue        4.451667   4.45   3.0   5.0
# blueBlack   4.266667   4.40   2.8   5.0
# dblack      4.570000   4.55   4.0   5.0
# green       4.300000   4.45   3.5   5.0
# greenBlue   4.425000   4.50   4.0   4.8

# %%
crested_butte_df.set_index("difficulty")
# Out:
#                  id                           name               type  \
# difficulty
# black       3671983      Monarch Crest - IMBA EPIC  Recommended Route
# blueBlack    338027                 401 Trail Loop  Recommended Route
# black         42669                    Doctor Park  Recommended Route
# black        963897            Teocalli Ridge Loop  Recommended Route
# blueBlack    656218                    Strand Hill  Recommended Route
# ...             ...                            ...                ...
# blueBlack   7049099                      Centipede              Trail
# greenBlue   5724886  Vail Pass to Copper Bike Path              Trail
# blue        4755628                   Wheelers Way              Trail
# greenBlue   5724988     Copper to Frisco Bike Path              Trail
# black        750887               Upper Upper Loop              Trail
#
#                                                       summary  stars  \
# difficulty
# black       One of Colorado's top 5 epic rides - classic h...    4.7
# blueBlack   The Crested Butte mega classic! High alpine me...    4.7
# black       A local favorite with a tough grind of a climb...    4.6
# black       A tough climb, great views, and a fun, long do...    4.6
# blueBlack                One of the best rides in the valley.    4.4
# ...                                                       ...    ...
# blueBlack   This is a multidirectional trail that can be u...    4.5
# greenBlue   A great tourist shuttle ride, or a great workout.    4.2
# blue        A great loop with awesome descents in either d...    4.0
# greenBlue   An excellent component of the Summit County Re...    4.3
# black       A steep technical uphill and a fast steep desc...    3.5
#
#             starVotes       location  \
# difficulty
# black             300  crested_butte
# blueBlack         329  crested_butte
# black             198  crested_butte
# black             117  crested_butte
# blueBlack          98  crested_butte
# ...               ...            ...
# blueBlack           2  crested_butte
# greenBlue           6  crested_butte
# blue               11  crested_butte
# greenBlue           4  crested_butte
# black              21  crested_butte
#
#                                                           url  \
# difficulty
# black       https://www.mtbproject.com/trail/3671983/monar...
# blueBlack   https://www.mtbproject.com/trail/338027/401-tr...
# black       https://www.mtbproject.com/trail/42669/doctor-...
# black       https://www.mtbproject.com/trail/963897/teocal...
# blueBlack   https://www.mtbproject.com/trail/656218/strand...
# ...                                                       ...
# blueBlack   https://www.mtbproject.com/trail/7049099/centi...
# greenBlue   https://www.mtbproject.com/trail/5724886/vail-...
# blue        https://www.mtbproject.com/trail/4755628/wheel...
# greenBlue   https://www.mtbproject.com/trail/5724988/coppe...
# black       https://www.mtbproject.com/trail/750887/upper-...
#
#                                                    imgSqSmall  \
# difficulty
# black       https://cdn2.apstatic.com/photos/mtb/7013256_s...
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7004088_s...
# black          https://i.vimeocdn.com/video/494611652_640.jpg
# black       https://img.youtube.com/vi/6fwbUcCzL8I/hqdefau...
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7005437_s...
# ...                                                       ...
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7032331_s...
# greenBlue   https://cdn2.apstatic.com/photos/mtb/5725250_s...
# blue        https://cdn2.apstatic.com/photos/mtb/7033271_s...
# greenBlue   https://cdn2.apstatic.com/photos/mtb/5725251_s...
# black       https://cdn2.apstatic.com/photos/mtb/7014327_s...
#
#                                                      imgSmall  ... length  \
# difficulty                                                     ...
# black       https://cdn2.apstatic.com/photos/mtb/7013256_s...  ...   36.2
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7004088_s...  ...   14.1
# black          https://i.vimeocdn.com/video/494611652_640.jpg  ...   20.1
# black       https://img.youtube.com/vi/6fwbUcCzL8I/hqdefau...  ...   11.5
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7005437_s...  ...    7.5
# ...                                                       ...  ...    ...
# blueBlack   https://cdn2.apstatic.com/photos/mtb/7032331_s...  ...    0.2
# greenBlue   https://cdn2.apstatic.com/photos/mtb/5725250_s...  ...    4.4
# blue        https://cdn2.apstatic.com/photos/mtb/7033271_s...  ...    1.6
# greenBlue   https://cdn2.apstatic.com/photos/mtb/5725251_s...  ...    6.6
# black       https://cdn2.apstatic.com/photos/mtb/7014327_s...  ...    2.6
#
#            ascent  descent   high    low  longitude  latitude  \
# difficulty
# black        2035    -5890  11962   7458  -106.3254   38.4965
# blueBlack    2249    -2222  11335   9584  -106.9937   38.9661
# black        2734    -2719  10913   8335  -106.7580   38.7301
# black        2149    -2146  11247   9135  -106.8852   38.8969
# blueBlack     874     -874   9752   8917  -106.9130   38.8644
# ...           ...      ...    ...    ...        ...       ...
# blueBlack       3      -99   5571   5472  -107.6886   38.7886
# greenBlue       5     -765  10537   9777  -106.2176   39.5261
# blue          200     -188  10345  10148  -106.2826   39.2222
# greenBlue      11     -652   9758   9117  -106.1357   39.4974
# black         390     -475   9441   9033  -106.9530   38.8732
#
#             conditionStatus  conditionDetails        conditionDate
# difficulty
# black             All Clear        Mostly Dry  2020-07-18 22:20:48
# blueBlack         All Clear               Dry  2020-07-18 15:29:09
# black             All Clear        Mostly Dry  2020-07-18 12:18:00
# black             All Clear               Dry  2020-07-09 15:17:25
# blueBlack         All Clear               Dry  2020-07-12 11:53:22
# ...                     ...               ...                  ...
# blueBlack           Unknown              None  1970-01-01 00:00:00
# greenBlue           Unknown              None  1970-01-01 00:00:00
# blue                Unknown              None  1970-01-01 00:00:00
# greenBlue           Unknown              None  1970-01-01 00:00:00
# black             All Clear                    2020-07-11 11:45:26
#
# [200 rows x 22 columns]

# %%
crested_butte_df.sort_index()
# Out:
#           id                           name               type  \
# 0    3671983      Monarch Crest - IMBA EPIC  Recommended Route
# 1     338027                 401 Trail Loop  Recommended Route
# 2      42669                    Doctor Park  Recommended Route
# 3     963897            Teocalli Ridge Loop  Recommended Route
# 4     656218                    Strand Hill  Recommended Route
# ..       ...                            ...                ...
# 195  7049099                      Centipede              Trail
# 196  5724886  Vail Pass to Copper Bike Path              Trail
# 197  4755628                   Wheelers Way              Trail
# 198  5724988     Copper to Frisco Bike Path              Trail
# 199   750887               Upper Upper Loop              Trail
#
#                                                summary difficulty  stars  \
# 0    One of Colorado's top 5 epic rides - classic h...      black    4.7
# 1    The Crested Butte mega classic! High alpine me...  blueBlack    4.7
# 2    A local favorite with a tough grind of a climb...      black    4.6
# 3    A tough climb, great views, and a fun, long do...      black    4.6
# 4                 One of the best rides in the valley.  blueBlack    4.4
# ..                                                 ...        ...    ...
# 195  This is a multidirectional trail that can be u...  blueBlack    4.5
# 196  A great tourist shuttle ride, or a great workout.  greenBlue    4.2
# 197  A great loop with awesome descents in either d...       blue    4.0
# 198  An excellent component of the Summit County Re...  greenBlue    4.3
# 199  A steep technical uphill and a fast steep desc...      black    3.5
#
#      starVotes       location  \
# 0          300  crested_butte
# 1          329  crested_butte
# 2          198  crested_butte
# 3          117  crested_butte
# 4           98  crested_butte
# ..         ...            ...
# 195          2  crested_butte
# 196          6  crested_butte
# 197         11  crested_butte
# 198          4  crested_butte
# 199         21  crested_butte
#
#                                                    url  \
# 0    https://www.mtbproject.com/trail/3671983/monar...
# 1    https://www.mtbproject.com/trail/338027/401-tr...
# 2    https://www.mtbproject.com/trail/42669/doctor-...
# 3    https://www.mtbproject.com/trail/963897/teocal...
# 4    https://www.mtbproject.com/trail/656218/strand...
# ..                                                 ...
# 195  https://www.mtbproject.com/trail/7049099/centi...
# 196  https://www.mtbproject.com/trail/5724886/vail-...
# 197  https://www.mtbproject.com/trail/4755628/wheel...
# 198  https://www.mtbproject.com/trail/5724988/coppe...
# 199  https://www.mtbproject.com/trail/750887/upper-...
#
#                                             imgSqSmall  ... length ascent  \
# 0    https://cdn2.apstatic.com/photos/mtb/7013256_s...  ...   36.2   2035
# 1    https://cdn2.apstatic.com/photos/mtb/7004088_s...  ...   14.1   2249
# 2       https://i.vimeocdn.com/video/494611652_640.jpg  ...   20.1   2734
# 3    https://img.youtube.com/vi/6fwbUcCzL8I/hqdefau...  ...   11.5   2149
# 4    https://cdn2.apstatic.com/photos/mtb/7005437_s...  ...    7.5    874
# ..                                                 ...  ...    ...    ...
# 195  https://cdn2.apstatic.com/photos/mtb/7032331_s...  ...    0.2      3
# 196  https://cdn2.apstatic.com/photos/mtb/5725250_s...  ...    4.4      5
# 197  https://cdn2.apstatic.com/photos/mtb/7033271_s...  ...    1.6    200
# 198  https://cdn2.apstatic.com/photos/mtb/5725251_s...  ...    6.6     11
# 199  https://cdn2.apstatic.com/photos/mtb/7014327_s...  ...    2.6    390
#
#     descent   high    low  longitude  latitude  conditionStatus  \
# 0     -5890  11962   7458  -106.3254   38.4965        All Clear
# 1     -2222  11335   9584  -106.9937   38.9661        All Clear
# 2     -2719  10913   8335  -106.7580   38.7301        All Clear
# 3     -2146  11247   9135  -106.8852   38.8969        All Clear
# 4      -874   9752   8917  -106.9130   38.8644        All Clear
# ..      ...    ...    ...        ...       ...              ...
# 195     -99   5571   5472  -107.6886   38.7886          Unknown
# 196    -765  10537   9777  -106.2176   39.5261          Unknown
# 197    -188  10345  10148  -106.2826   39.2222          Unknown
# 198    -652   9758   9117  -106.1357   39.4974          Unknown
# 199    -475   9441   9033  -106.9530   38.8732        All Clear
#
#      conditionDetails        conditionDate
# 0          Mostly Dry  2020-07-18 22:20:48
# 1                 Dry  2020-07-18 15:29:09
# 2          Mostly Dry  2020-07-18 12:18:00
# 3                 Dry  2020-07-09 15:17:25
# 4                 Dry  2020-07-12 11:53:22
# ..                ...                  ...
# 195              None  1970-01-01 00:00:00
# 196              None  1970-01-01 00:00:00
# 197              None  1970-01-01 00:00:00
# 198              None  1970-01-01 00:00:00
# 199                    2020-07-11 11:45:26
#
# [200 rows x 23 columns]

# %%
crested_butte_df.corr(method ='pearson')
# Out:
#                  id     stars  starVotes    length    ascent   descent  \
# id         1.000000  0.019596  -0.388554  0.140973  0.112284 -0.110553
# stars      0.019596  1.000000   0.096621  0.033654  0.000517 -0.076974
# starVotes -0.388554  0.096621   1.000000  0.033575  0.013360 -0.068584
# length     0.140973  0.033654   0.033575  1.000000  0.957520 -0.940367
# ascent     0.112284  0.000517   0.013360  0.957520  1.000000 -0.932548
# descent   -0.110553 -0.076974  -0.068584 -0.940367 -0.932548  1.000000
# high      -0.103228  0.249389   0.124396  0.360460  0.408236 -0.495082
# low       -0.194277  0.278182   0.030368 -0.185963 -0.152837  0.123518
# longitude -0.051585  0.202148   0.052816  0.056832  0.065177 -0.133929
# latitude  -0.090880 -0.003159  -0.085933 -0.081868 -0.032963  0.048467
#
#                high       low  longitude  latitude
# id        -0.103228 -0.194277  -0.051585 -0.090880
# stars      0.249389  0.278182   0.202148 -0.003159
# starVotes  0.124396  0.030368   0.052816 -0.085933
# length     0.360460 -0.185963   0.056832 -0.081868
# ascent     0.408236 -0.152837   0.065177 -0.032963
# descent   -0.495082  0.123518  -0.133929  0.048467
# high       1.000000  0.735894   0.651378  0.033557
# low        0.735894  1.000000   0.602864  0.036762
# longitude  0.651378  0.602864   1.000000  0.203710
# latitude   0.033557  0.036762   0.203710  1.000000

# %%
text = " ".join(review for review in crested_butte_df.summary)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 14482 words in the combination of all review.

# %%
crested_butte_df["summary"].head()
# Out:
# 0    One of Colorado's top 5 epic rides - classic h...
# 1    The Crested Butte mega classic! High alpine me...
# 2    A local favorite with a tough grind of a climb...
# 3    A tough climb, great views, and a fun, long do...
# 4                 One of the best rides in the valley.
# Name: summary, dtype: object

# %%
stopwords = set(STOPWORDS)
stopwords.update(["singletrack","trail","great","ride","climb","descent"])

# %%
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# MTB_Trail_Data_EDA

# %%
all_df = pd.concat([crested_butte_df, marin_county_df, denver_df, park_city_df, sedona_df, moab_df])

# %%
print(all_df.tail())
# Out:
#           id                                  name   type  \
# 195  7006956  Rabbit Valley 8 Parallel Doubletrack  Trail
# 196   194966                          Cross Canyon  Trail
# 197  7025695                             Malachite  Trail
# 198  7004959              Reservoir - 1 Trail #663  Trail
# 199   171772                     Hunter Canyon Rim  Trail
#
#                                                summary difficulty  stars  \
# 195  A great alternative, or bailout from the ultra...       blue    3.5
# 196  A great 'up' trail to connect different loops ...       blue    3.1
# 197                   An alternative route to Azurite.  blueBlack    3.5
# 198  A mixture of tough rooty climbs to get you up ...      black    3.5
# 199  One of the last "Old-School" Moab rides where ...      black    3.3
#
#      starVotes location                                                url  \
# 195          2     moab  https://www.mtbproject.com/trail/7006956/rabbi...
# 196         10     moab  https://www.mtbproject.com/trail/194966/cross-...
# 197          2     moab  https://www.mtbproject.com/trail/7025695/malac...
# 198          2     moab  https://www.mtbproject.com/trail/7004959/reser...
# 199          3     moab  https://www.mtbproject.com/trail/171772/hunter...
#
#                                             imgSqSmall  ... length ascent  \
# 195  https://cdn2.apstatic.com/photos/mtb/5010528_s...  ...    2.2    296
# 196  https://cdn2.apstatic.com/photos/mtb/582004_sq...  ...    1.3    137
# 197                                                     ...    0.9    150
# 198                                                     ...    1.2    374
# 199  https://cdn2.apstatic.com/photos/mtb/4608588_s...  ...    3.9    330
#
#     descent  high   low  longitude  latitude  conditionStatus  \
# 195     -86  4938  4718  -108.9871   39.1697          Unknown
# 196     -40  4632  4508  -109.6454   38.7046        All Clear
# 197    -107  4958  4809  -109.7090   38.7916          Unknown
# 198      -5  9541  9167  -108.7549   38.8480        All Clear
# 199    -811  4619  4048  -109.5639   38.4947          Unknown
#
#      conditionDetails        conditionDate
# 195              None  1970-01-01 00:00:00
# 196                    2020-05-18 13:40:53
# 197              None  1970-01-01 00:00:00
# 198                    2020-05-27 09:31:47
# 199              None  1970-01-01 00:00:00
#
# [5 rows x 23 columns]

# %%
all_df.describe()
# Out:
#                  id        stars    starVotes       length        ascent  \
# count  1.200000e+03  1200.000000  1200.000000  1200.000000   1200.000000
# mean   5.094509e+06     4.081250    22.534167     8.359750    934.098333
# std    2.570708e+06     0.566531    45.441717    19.021649   1801.593338
# min    3.180400e+04     0.000000     0.000000     0.100000      0.000000
# 25%    3.733141e+06     3.800000     3.000000     1.400000     78.000000
# 50%    7.001508e+06     4.000000     9.000000     3.150000    354.500000
# 75%    7.026000e+06     4.500000    22.000000     8.800000   1160.250000
# max    7.053888e+06     5.000000   570.000000   294.300000  21408.000000
#
#             descent          high           low    longitude     latitude
# count   1200.000000   1200.000000   1200.000000  1200.000000  1200.000000
# mean   -1021.329167   6218.566667   5443.849167  -111.282606    38.479742
# std     1797.542571   3042.419928   2745.875860     5.510290     1.881793
# min   -22549.000000     23.000000   -303.000000  -123.334600    34.151300
# 25%    -1234.750000   4666.750000   4366.000000  -111.932350    37.900025
# 50%     -464.000000   6187.000000   5638.000000  -110.918500    38.787350
# 75%     -142.500000   8366.500000   7478.250000  -106.927775    39.757350
# max        0.000000  14418.000000  11840.000000  -104.762600    41.291700

# %%
text = " ".join(review for review in all_df.summary)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 81198 words in the combination of all review.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["This"])

# %%
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
all_df.corr(method ='pearson')
# Out:
#                  id     stars  starVotes    length    ascent   descent  \
# id         1.000000  0.045770  -0.334008  0.051266  0.046786 -0.044421
# stars      0.045770  1.000000   0.099660  0.036089  0.016942 -0.074568
# starVotes -0.334008  0.099660   1.000000  0.051048  0.047924 -0.098295
# length     0.051266  0.036089   0.051048  1.000000  0.917947 -0.898894
# ascent     0.046786  0.016942   0.047924  0.917947  1.000000 -0.933163
# descent   -0.044421 -0.074568  -0.098295 -0.898894 -0.933163  1.000000
# high      -0.057485  0.136733   0.100233  0.209388  0.265797 -0.325633
# low       -0.068025  0.130740   0.065391  0.017359  0.040642 -0.091630
# longitude -0.168347  0.024644   0.219072  0.102930  0.104042 -0.140504
# latitude  -0.019318  0.008155   0.098377 -0.000150  0.044542 -0.051624
#
#                high       low  longitude  latitude
# id        -0.057485 -0.068025  -0.168347 -0.019318
# stars      0.136733  0.130740   0.024644  0.008155
# starVotes  0.100233  0.065391   0.219072  0.098377
# length     0.209388  0.017359   0.102930 -0.000150
# ascent     0.265797  0.040642   0.104042  0.044542
# descent   -0.325633 -0.091630  -0.140504 -0.051624
# high       1.000000  0.957718   0.814044  0.284233
# low        0.957718  1.000000   0.841151  0.270633
# longitude  0.814044  0.841151   1.000000  0.294215
# latitude   0.284233  0.270633   0.294215  1.000000

# %%
sns.pairplot(all_df)
plt.show()

# %%
all_df.groupby("location")["stars"].agg([np.min,np.max,np.mean,np.median])
